# %%
import pyspark.sql.functions as F
import pyspark.sql.types as T

# %%
schema = T.StructType([
    T.StructField("id", T.IntegerType(), True),
    T.StructField("name", T.StringType(), True),
    T.StructField("values", T.ArrayType(
        T.StructType([
            T.StructField("val1", T.IntegerType(), True),
            T.StructField("val2", T.IntegerType(), True)
        ])
    ), True)
])

# %%
data = [(1, "John", [{"val1": 1, "val2": 2}, {"val1": 3, "val2": 4}]),
        (2, "Jane", [{"val1": 5, "val2": 6}, {"val1": 7, "val2": 8}]),
        (3, "Bob", [{"val1": 9, "val2": 10}, {"val1": 11, "val2": 12}])]

# Create the DataFrame
df = spark.createDataFrame(data, schema)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>values</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>List(List(1, 2), List(3, 4))</td></tr><tr><td>2</td><td>Jane</td><td>List(List(5, 6), List(7, 8))</td></tr><tr><td>3</td><td>Bob</td><td>List(List(9, 10), List(11, 12))</td></tr></tbody></table></div>

# %%
df_explode = df.select(F.col("id"), F.col("name"), F.explode(F.col("values")).alias("dictionary_data"))

# %%
df_explode.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dictionary_data</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>List(1, 2)</td></tr><tr><td>1</td><td>John</td><td>List(3, 4)</td></tr><tr><td>2</td><td>Jane</td><td>List(5, 6)</td></tr><tr><td>2</td><td>Jane</td><td>List(7, 8)</td></tr><tr><td>3</td><td>Bob</td><td>List(9, 10)</td></tr><tr><td>3</td><td>Bob</td><td>List(11, 12)</td></tr></tbody></table></div>

# %%
df_parse = (df_explode \
            .select(F.col("*"), \
                              F.col("dictionary_data.val1").alias("value_1"), F.col("dictionary_data.val2").alias("value_2")) \
            .drop("dictionary_data")
           )

# %%
df_parse.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>value_1</th><th>value_2</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>1</td><td>2</td></tr><tr><td>1</td><td>John</td><td>3</td><td>4</td></tr><tr><td>2</td><td>Jane</td><td>5</td><td>6</td></tr><tr><td>2</td><td>Jane</td><td>7</td><td>8</td></tr><tr><td>3</td><td>Bob</td><td>9</td><td>10</td></tr><tr><td>3</td><td>Bob</td><td>11</td><td>12</td></tr></tbody></table></div>
