# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('CustomerData.csv', engine='python')

# %%
data.head()
# Out:
#    customerNo      firstName  middleName lastName                  email  \
# 0           1  MicheXXeNariD         NaN      NaN  a_zahidpk@hotmail.com
# 1           2   DolBnNeville         NaN      NaN       mkaur@Dooney.com
# 2           3   DolBnNeville         NaN      NaN  a_zahidpk@hotmail.com
# 3           4   DolBnNeville         NaN      NaN  a_zahidpk@hotmail.com
# 4           5  MicheXXeNariD         NaN      NaN  a_zahidpk@hotmail.com
#
#          phone        address      zipCode                            city  \
# 0   6099479471  GORNIAK drive       154966             Central and Western
# 1  33333333333        Unit 02   14th Floor                          193361
# 2   6099479471        Unit 02   14th Floor   Kodak House II 39 Healthy Str
# 3   6099479471        Unit 02   14th Floor   Kodak House II 39 Healthy Str
# 4   6099479471  GORNIAK drive       154966                          parlin
#
#                  state  ... PRIMARYCONTACTPHONEEXTENSION RECEIPTOPTION  \
# ...

# %%
#Data Exploration ...............................
# Columns
data.columns
# Out:
# Index(['customerNo', 'firstName', 'middleName', 'lastName', 'email', 'phone',
#        'address', 'zipCode', 'city', 'state',
#        ...
#        'PRIMARYCONTACTPHONEEXTENSION', 'RECEIPTOPTION', 'SALESTAXGROUP',
#        'TRANSFERSTATUS', 'Phone_ProcessIndicator', 'Address_ProcessIndicator',
#        'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105'],
#       dtype='object', length=106)

# %%
# unique values
data['firstName'].unique()
# Out:
# array(['MicheXXeNariD', 'DolBnNeville', 'SysonnRaNos', ...,
#        'RudyBrdANRthhyst', 'StRphhBniRINani', 'MelissaLong'], dtype=object)

# %%
# Describe
data.describe()
# Out:
#          customerNo  middleName  maritalStatus  gender  languagePreference  \
# count  20000.000000         0.0            0.0     0.0                 0.0
# mean   10000.500000         NaN            NaN     NaN                 NaN
# std     5773.647028         NaN            NaN     NaN                 NaN
# min        1.000000         NaN            NaN     NaN                 NaN
# 25%     5000.750000         NaN            NaN     NaN                 NaN
# 50%    10000.500000         NaN            NaN     NaN                 NaN
# 75%    15000.250000         NaN            NaN     NaN                 NaN
# max    20000.000000         NaN            NaN     NaN                 NaN
#
#        partyCountry  partyState  guestCustomerInd  billingAddress  \
# count           0.0         0.0               0.0             0.0
# mean            NaN         NaN               NaN             NaN
# std             NaN         NaN               NaN             NaN
# ...

# %%
# Duplicates
data[data[['email']].duplicated() == True].head()
# Out:
#    customerNo      firstName  middleName lastName  \
# 2           3   DolBnNeville         NaN      NaN
# 3           4   DolBnNeville         NaN      NaN
# 4           5  MicheXXeNariD         NaN      NaN
# 8           9    SysonnRaNos         NaN      NaN
# 9          10    SysonnRaNos         NaN      NaN
#
#                                 email       phone        address  \
# 2               a_zahidpk@hotmail.com  6099479471        Unit 02
# 3               a_zahidpk@hotmail.com  6099479471        Unit 02
# 4               a_zahidpk@hotmail.com  6099479471  GORNIAK drive
# 8  khurram.saleem@visionetsystems.com  2123127618      Room 5183
# 9  khurram.saleem@visionetsystems.com  2123127618      Room 5183
#
#                     zipCode                            city   state  ...  \
# 2                14th Floor   Kodak House II 39 Healthy Str  178189  ...
# 3                14th Floor   Kodak House II 39 Healthy Str  178189  ...
# ...

# %%
data[data['middleName'].notnull()]
# Out:
# Empty DataFrame
# ...

# %%
#Since all middle Names are NaN so we can delete that column
data = data.drop('middleName', axis=1)

# %%
data.head()
# Out:
#    customerNo      firstName lastName                  email        phone  \
# 0           1  MicheXXeNariD      NaN  a_zahidpk@hotmail.com   6099479471
# 1           2   DolBnNeville      NaN       mkaur@Dooney.com  33333333333
# 2           3   DolBnNeville      NaN  a_zahidpk@hotmail.com   6099479471
# 3           4   DolBnNeville      NaN  a_zahidpk@hotmail.com   6099479471
# 4           5  MicheXXeNariD      NaN  a_zahidpk@hotmail.com   6099479471
#
#          address      zipCode                            city  \
# 0  GORNIAK drive       154966             Central and Western
# 1        Unit 02   14th Floor                          193361
# 2        Unit 02   14th Floor   Kodak House II 39 Healthy Str
# 3        Unit 02   14th Floor   Kodak House II 39 Healthy Str
# 4  GORNIAK drive       154966                          parlin
#
#                  state     country  ... PRIMARYCONTACTPHONEEXTENSION  \
# 0           Hong Kong          USA  ...                          NaN
# ...
