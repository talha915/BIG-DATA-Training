# %%
import pandas as pd
import json

# %%
json_data = pd.read_json('information.json')

# %%
f = open('information.json','r')
json_data = json.load(f)

# %%
json_data
# Out:
# [{'Certifications': [None],
#   'Email': ['abdulrehman09@outlook.com'],
#   'Name': 'RnD Computer',
#   'Phone_no': ['+92 332 4310929'],
#   'Qualification': ['be computer engineering'],
#   'Skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex'],
#   'University': ['national university of sciences & technology']},
#  {'Certifications': [None],
#   'Email': ['13herger@gmail.com'],
#   'Name': 'Brendan Herger',
#   'Phone_no': ['1 (415) 582-7457'],
#   'Qualification': ['university of san francisco july 2015'],
#   'Skills': None,
#   'University': ['university of san francisco may 2014']},
#  {'Certifications': [None],
#   'Email': ['kirankss@gmail.com;'],
#   'Name': 'SURYAKIRAN KASTURI',
#   'Phone_no': ['+91-9448821250'],
#   'Qualification': ['bachelor of engineering (electronics and communication); malnad college of engineering hassan (mce); 1999'],
#   'Skills': None,
#   'University': ['designation r & d manager (equivalent to sr engineering manager)']},
#  {'Certifications': [None],
#   'Email': ['abdulrehman09@outlook.com'],
#   'Name': 'RnD Computer',
#   'Phone_no': ['+92 332 4310929'],
#   'Qualification': ['be computer engineering'],
#   'Skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex'],
#   'University': ['national university of sciences & technology']},
#  {'Certifications': [None],
#   'Email': ['sresume@kent.edu'],
#   'Name': 'John Smith',
#   'Phone_no': ['614-555-5555'],
#   'Qualification': ['kent state university'],
#   'Skills': ['Microsoft',
#    'Office',
#    'Word',
#    'PowerPoint',
#    'Excel',
#    'SQL',
#    'Structure',
#    'Query',
#    'Language',
#    'Programs',
#    'Adobe',
#    'Photoshop',
#    'Movie',
#    'Maker',
#    'Social',
#    'Media',
#    'Administration',
#    'LinkedIn',
#    'Twitter',
#    'Instagram',
#    'Facebook',
#    'WORK',
#    'EXPERIENCE',
#    'Kent',
#    'State',
#    'University',
#    'Kent',
#    'Ohio',
#    'Resident',
#    'Advisor',
#    'Collaborate',
#    'Graduation',
#    'May',
#    'Kent',
#    'Ohio',
#    'GPA',
#    'August',
#    'Present'],
#   'University': ['kent state university kent ohio']},
#  {'Certifications': ['Environmental & Engineering division • Business development/ Project Engineer the bidding process October 2014 – November 2016 ◦ Management of commercial aspects by liaising with multiple teams for water and wastewater treatment projects to streamline Dubai , AE/ Lahore , PK ◦ Water demand estimation and hydraulic design for piping networks of water supply system projects using EPANET ◦ Analysis of key design metrics of wastewater treatment plants by consideration of piping , pump selection and reactor to formulate improved technical design proposals through Failure Modes & Effects Analysis ( FMEA ) for the customer ◦ Successful acquisition of Franklin Electric authorized product line distribution for 3W Systems as a part of the international assignment GIK Insitute of Engineering Sciences & Technology ( GIKI ) Department of Mechanical Engineering • Bachelor Thesis & Research Student Topic : “ Design and Development of an Aerodynamic Downforce Package for Formula Student Racecar ” ◦ Design , modeling and simulation aerodynamic devices using Solidworks , ANSYS Fluent and CFX ◦ Construction and execution of the Wind\xadtunnel setup to validate the design performance ◦ Evaluation of final performance with designed aerodynamic devices using FSAE ( Formula Society of Automotive Engineers ) Lap\xadtime simulator on FSAE California 2011 track map to achieve a 2.7 second improvement ( in terms of autocross lap\xadtimes ) April 2013 – April 2014 Topi , PK Educational Background Aachen University of Applied Sciences ( FH Aachen ) • Master of Science , Automotive Engineering , pre\xadthesis grade 1.80/5.00 Specialization : Controls development & Powertrain application GIK Institute of Engineering Sciences and Technology ( GIKI ) • Bachelor of Science , Mechanical Engineering Specialization : Fluid Mechanics Proficiencies Aachen , DE Since March 2017 Topi , PK August 2010 – June 2014 Foreign Languages Computer Skills Certifications → Deutsch – GeR Niveau\xadstufe B1 → English – GeR Niveau\xadstufe C1 → MATLAB/ Simulink/ Stateflow , LabVIEW → C/C++ , Python , VBA → Microsoft Office suite , Visio → LATEX → ECU\xadTEST → In\xadstep , IBM DOORs , JIRA → SVN Tortoise → CATIA V5 , Solidworks → TU Delft – Electric Cars Technology → Microsoft – Python Fundamentals → Mathworks – MATLAB ( Onramp , Fundamentals , Data Processing and Visualization ) , Stateflow Onramp , Simulink Onramp Driving Expertise → License – Class B * References available upon request'],
#   'Email': ['ammad.ahmad@alumni.fh\xadaachen.com'],
#   'Name': 'Ammad Ahmad',
#   'Phone_no': ['+49 176 86298926'],
#   'Qualification': ['environmental & engineering division'],
#   'Skills': ['Certifications',
#    'Deutsch',
#    'GeR',
#    'English',
#    'GeR',
#    'Stateflow',
#    'LabVIEW',
#    'Python',
#    'VBA',
#    'Microsoft',
#    'Office',
#    'Visio',
#    'LATEX',
#    'IBM',
#    'DOORs',
#    'JIRA',
#    'SVN',
#    'Tortoise',
#    'CATIA',
#    'Solidworks',
#    'TU',
#    'Delft',
#    'Electric',
#    'Cars',
#    'Technology',
#    'Microsoft',
#    'Python',
#    'Fundamentals',
#    'Mathworks',
#    'MATLAB',
#    'Onramp',
#    'Fundamentals',
#    'Data',
#    'Processing',
#    'Visualization',
#    'Stateflow',
#    'Onramp',
#    'Simulink',
#    'Onramp',
#    'Driving',
#    'Expertise',
#    'License',
#    'Class',
#    'B',
#    'References'],
#   'University': ['gik insitute of engineering sciences & technology (giki)']},
#  {'Certifications': [None],
#   'Email': ['kirankss@gmail.com;'],
#   'Name': 'SURYAKIRAN KASTURI',
#   'Phone_no': ['+91-9448821250'],
#   'Qualification': ['bachelor of engineering (electronics and communication); malnad college of engineering hassan (mce); 1999'],
#   'Skills': None,
#   'University': ['designation r & d manager (equivalent to sr engineering manager)']},
#  {'Certifications': [None],
#   'Email': ['abdulrehman09@outlook.com'],
#   'Name': 'RnD Computer',
#   'Phone_no': ['+92 332 4310929'],
#   'Qualification': ['be computer engineering'],
#   'Skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex'],
#   'University': ['national university of sciences & technology']},
#  {'Certifications': [None],
#   'Email': ['sresume@kent.edu'],
#   'Name': 'John Smith',
#   'Phone_no': ['614-555-5555'],
#   'Qualification': ['kent state university'],
#   'Skills': ['Microsoft',
#    'Office',
#    'Word',
#    'PowerPoint',
#    'Excel',
#    'SQL',
#    'Structure',
#    'Query',
#    'Language',
#    'Programs',
#    'Adobe',
#    'Photoshop',
#    'Movie',
#    'Maker',
#    'Social',
#    'Media',
#    'Administration',
#    'LinkedIn',
#    'Twitter',
#    'Instagram',
#    'Facebook',
#    'WORK',
#    'EXPERIENCE',
#    'Kent',
#    'State',
#    'University',
#    'Kent',
#    'Ohio',
#    'Resident',
#    'Advisor',
#    'Collaborate',
#    'Graduation',
#    'May',
#    'Kent',
#    'Ohio',
#    'GPA',
#    'August',
#    'Present'],
#   'University': ['kent state university kent ohio']}]

# %%
def get_skills(json_data): 
    final_result = []
    for i in range(0, len(json_data)):
        result = {}
        skills = json_data[i]['Skills'] 
        name = json_data[i]['Name']
        result['name'] = name
        result['skills'] = skills
        final_result.append(result)
    return final_result

# %%
skills_data = get_skills(json_data)

# %%
skills_data
# Out:
# [{'name': 'RnD Computer',
#   'skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex']},
#  {'name': 'Brendan Herger', 'skills': None},
#  {'name': 'SURYAKIRAN KASTURI', 'skills': None},
#  {'name': 'RnD Computer',
#   'skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex']},
#  {'name': 'John Smith',
#   'skills': ['Microsoft',
#    'Office',
#    'Word',
#    'PowerPoint',
#    'Excel',
#    'SQL',
#    'Structure',
#    'Query',
#    'Language',
#    'Programs',
#    'Adobe',
#    'Photoshop',
#    'Movie',
#    'Maker',
#    'Social',
#    'Media',
#    'Administration',
#    'LinkedIn',
#    'Twitter',
#    'Instagram',
#    'Facebook',
#    'WORK',
#    'EXPERIENCE',
#    'Kent',
#    'State',
#    'University',
#    'Kent',
#    'Ohio',
#    'Resident',
#    'Advisor',
#    'Collaborate',
#    'Graduation',
#    'May',
#    'Kent',
#    'Ohio',
#    'GPA',
#    'August',
#    'Present']},
#  {'name': 'Ammad Ahmad',
#   'skills': ['Certifications',
#    'Deutsch',
#    'GeR',
#    'English',
#    'GeR',
#    'Stateflow',
#    'LabVIEW',
#    'Python',
#    'VBA',
#    'Microsoft',
#    'Office',
#    'Visio',
#    'LATEX',
#    'IBM',
#    'DOORs',
#    'JIRA',
#    'SVN',
#    'Tortoise',
#    'CATIA',
#    'Solidworks',
#    'TU',
#    'Delft',
#    'Electric',
#    'Cars',
#    'Technology',
#    'Microsoft',
#    'Python',
#    'Fundamentals',
#    'Mathworks',
#    'MATLAB',
#    'Onramp',
#    'Fundamentals',
#    'Data',
#    'Processing',
#    'Visualization',
#    'Stateflow',
#    'Onramp',
#    'Simulink',
#    'Onramp',
#    'Driving',
#    'Expertise',
#    'License',
#    'Class',
#    'B',
#    'References']},
#  {'name': 'SURYAKIRAN KASTURI', 'skills': None},
#  {'name': 'RnD Computer',
#   'skills': ['Programming',
#    'Languages',
#    'Tools',
#    'Libraries',
#    'Matlab',
#    'C',
#    'C',
#    'Python',
#    'Assembly',
#    'Microsoft',
#    'Visual',
#    'Studio',
#    'EmguCV',
#    'Weka',
#    'OpenCv',
#    'LaTex']},
#  {'name': 'John Smith',
#   'skills': ['Microsoft',
#    'Office',
#    'Word',
#    'PowerPoint',
#    'Excel',
#    'SQL',
#    'Structure',
#    'Query',
#    'Language',
#    'Programs',
#    'Adobe',
#    'Photoshop',
#    'Movie',
#    'Maker',
#    'Social',
#    'Media',
#    'Administration',
#    'LinkedIn',
#    'Twitter',
#    'Instagram',
#    'Facebook',
#    'WORK',
#    'EXPERIENCE',
#    'Kent',
#    'State',
#    'University',
#    'Kent',
#    'Ohio',
#    'Resident',
#    'Advisor',
#    'Collaborate',
#    'Graduation',
#    'May',
#    'Kent',
#    'Ohio',
#    'GPA',
#    'August',
#    'Present']}]

# %%
csv_data = pd.read_csv('jobdescript.csv')

# %%
csv_data
# Out:
#              Statistics     Machine Learning  \
# 0    statistical models    linear regression
# 1  statistical modeling  logistic regression
# 2           probability              K means
# 3   normal distribution        random forest
# 4  poisson distribution              xgboost
# 5    hypothesis testing                  svm
# 6       factor analysis                  pca
# 7           forecasting       decision trees
#
#                         Deep Learning R Language Python Language  \
# 0                      neural network          r          python
# 1                               keras     ggplot           flask
# 2                              theano      shiny          django
# 3                      face detection       cran          pandas
# 4                     neural networks      dplyr           numpy
# 5  convolutional neural network (cnn)      tidyr     scikitlearn
# 6       recurrent neural network(RNN)  lubridate         sklearn
# 7                    object detection      knitr      matplotlib
#
#                            NLP Data Engineering
# 0                          nlp              aws
# 1  natural language processing              ec2
# 2               topic modeling  amazon redshift
# 3                          lda               s3
# 4     named entity recognition           docker
# 5                  pos tagging       kubernetes
# 6                     word2vec            scala
# 7               word embedding         teradata

# %%
stats_words = [(text) for text in csv_data['Statistics'].dropna(axis = 0)]
ml = [(text) for text in csv_data['Machine Learning'].dropna(axis = 0)]
dl = [(text) for text in csv_data['Deep Learning'].dropna(axis = 0)]
rl = [(text) for text in csv_data['R Language'].dropna(axis = 0)]
python_lang = [(text) for text in csv_data['Python Language'].dropna(axis = 0)]
nlp  = [(text) for text in csv_data['NLP'].dropna(axis = 0)]
data_eng = [(text) for text in csv_data['Data Engineering'].dropna(axis = 0)]

# %%
stats_words
# Out:
# ['statistical models',
#  'statistical modeling',
#  'probability',
#  'normal distribution',
#  'poisson distribution',
#  'hypothesis testing',
#  'factor analysis',
#  'forecasting']

# %%
for i in range(0, len(skills_data)):
    if(type(skills_data[i]['skills']) == list):
        skills_data[i]['skills'] = list(map(lambda x: x.lower(), skills_data[i]['skills']))
        print(skills_data[i])
# Out:
# {'name': 'RnD Computer', 'skills': ['programming', 'languages', 'tools', 'libraries', 'matlab', 'c', 'c', 'python', 'assembly', 'microsoft', 'visual', 'studio', 'emgucv', 'weka', 'opencv', 'latex']}
# {'name': 'RnD Computer', 'skills': ['programming', 'languages', 'tools', 'libraries', 'matlab', 'c', 'c', 'python', 'assembly', 'microsoft', 'visual', 'studio', 'emgucv', 'weka', 'opencv', 'latex']}
# {'name': 'John Smith', 'skills': ['microsoft', 'office', 'word', 'powerpoint', 'excel', 'sql', 'structure', 'query', 'language', 'programs', 'adobe', 'photoshop', 'movie', 'maker', 'social', 'media', 'administration', 'linkedin', 'twitter', 'instagram', 'facebook', 'work', 'experience', 'kent', 'state', 'university', 'kent', 'ohio', 'resident', 'advisor', 'collaborate', 'graduation', 'may', 'kent', 'ohio', 'gpa', 'august', 'present']}
# {'name': 'Ammad Ahmad', 'skills': ['certifications', 'deutsch', 'ger', 'english', 'ger', 'stateflow', 'labview', 'python', 'vba', 'microsoft', 'office', 'visio', 'latex', 'ibm', 'doors', 'jira', 'svn', 'tortoise', 'catia', 'solidworks', 'tu', 'delft', 'electric', 'cars', 'technology', 'microsoft', 'python', 'fundamentals', 'mathworks', 'matlab', 'onramp', 'fundamentals', 'data', 'processing', 'visualization', 'stateflow', 'onramp', 'simulink', 'onramp', 'driving', 'expertise', 'license', 'class', 'b', 'references']}
# {'name': 'RnD Computer', 'skills': ['programming', 'languages', 'tools', 'libraries', 'matlab', 'c', 'c', 'python', 'assembly', 'microsoft', 'visual', 'studio', 'emgucv', 'weka', 'opencv', 'latex']}
# {'name': 'John Smith', 'skills': ['microsoft', 'office', 'word', 'powerpoint', 'excel', 'sql', 'structure', 'query', 'language', 'programs', 'adobe', 'photoshop', 'movie', 'maker', 'social', 'media', 'administration', 'linkedin', 'twitter', 'instagram', 'facebook', 'work', 'experience', 'kent', 'state', 'university', 'kent', 'ohio', 'resident', 'advisor', 'collaborate', 'graduation', 'may', 'kent', 'ohio', 'gpa', 'august', 'present']}

# %%
skills_df = skills_df[3]['skills']
skills_df = list(map(lambda x: x.lower(), skills_df))
print(skills_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-e1129b3a71da> in <module>
# ----> 1 skills_df = skills_df[3]['skills']
#       2 skills_df = list(map(lambda x: x.lower(), skills_df))
#       3 print(skills_df)
#
# TypeError: string indices must be integers

# %%
same_values = set(skills_df) & set(stats_words)

# %%
print(same_values)
# Out:
# {'python'}
