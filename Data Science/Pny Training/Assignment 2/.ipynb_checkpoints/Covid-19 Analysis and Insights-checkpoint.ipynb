# %%
import pandas as pd

# %%
active_cases = 'Active_Cases.csv'

# %%
active_cases_data = pd.read_csv(active_cases)

# %%
active_cases_data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  9/27/20  9/28/20  9/29/20  \
# 0        0        0        0        0  ...    39227    39233    39254
# 1        0        0        0        0  ...    13259    13391    13518
# 2        0        0        0        0  ...    51067    51213    51368
# 3        0        0        0        0  ...     1836     1966     1966
# 4        0        0        0        0  ...     4718     4797     4905
#
#    9/30/20  10/1/20  10/2/20  10/3/20  10/4/20  10/5/20  10/6/20
# ...

# %%
#Active Cases across Pakistan, India , USA
selected_countries = ['Pakistan', 'India', 'US']

# %%
active_cases_selected_countries = active_cases_data[active_cases_data['Country/Region'].isin(selected_countries)]

# %%
active_cases_selected_countries
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 143            NaN          India  20.593684   78.96288        0        0
# 198            NaN       Pakistan  30.375300   69.34510        0        0
# 242            NaN             US  40.000000 -100.00000        1        1
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  9/27/20  9/28/20  9/29/20  \
# 143        0        0        0        0  ...  6074702  6145291  6225763
# 198        0        0        0        0  ...   310841   311516   312263
# 242        2        2        5        5  ...  7116225  7149537  7191637
#
#      9/30/20  10/1/20  10/2/20  10/3/20  10/4/20  10/5/20  10/6/20
# 143  6312584  6394068  6473544  6549373  6623815  6685082  6757131
# 198   312806   313431   313984   314616   314616   315727   316351
# 242  7233042  7277791  7332297  7382341  7417845  7457402  7500964
#
# [3 rows x 263 columns]
