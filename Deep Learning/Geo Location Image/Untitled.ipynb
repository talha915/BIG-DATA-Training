# %%
import os
import cv2
import numpy as np
import exifread
import matplotlib.pyplot as plt
from GPSPhoto import gpsphoto
import pandas as pd

# %%
test_dir = os.listdir('test/')

# %%
test_path = 'test/'

# %%
images_all = []
images_metadata = []

# %%
for i in test_dir:
    image = cv2.imread(test_path+i)
    data = gpsphoto.getGPSData(test_path+i)
#     f = open(test_path+i, 'rb')
    images_all.append(image)
    images_metadata.append(data)
    #tags = exifread.process_file(f)
#     for tag in tags.keys():
#         print("Key:%s, value:%s" % (tag, tags[tag]))

# %%
print(len(images_all))
# Out:
# 1

# %%
images_metadata[0]
# Out:
# {'Latitude': 55.86449189238991,
#  'Longitude': -4.4298895959595965,
#  'Altitude': 65.19,
#  'UTC-Time': '10:25:15',
#  'Date': '03/19/2019'}

# %%
plt.figure()
plt.imshow(images_all[0])

# %%
# Out:
# <ipython-input-21-d488fd509f0a>:1: DeprecationWarning: path should be string, bytes, or os.PathLike, not numpy.ndarray
#   f = open(images_all[0], 'r')
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-21-d488fd509f0a> in <module>
# ----> 1 f = open(images_all[0], 'r')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte
